# %%
print("ok")
# Out:
# ok

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# datalink : https://www.kaggle.com/datasets/ra4u12/bookrecommendation

# %%
import pandas as  pd
import numpy as np

# %%
books = pd.read_csv("BX-Books.csv", sep=";", error_bad_lines=False ,encoding="latin-1")
# Out:
# c:\Users\tanya\anaconda3\envs\books\lib\site-packages\IPython\core\interactiveshell.py:3552: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# ...

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.iloc[237]['Image-URL-M'] # 237th row, Image-URL-M column
# Out:
# 'http://images.amazon.com/images/P/0671027387.01.MZZZZZZZ.jpg'

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books.rename(columns={"ISBN":'isbn',"Book-Title":"title", "Book-Author":"author", "Year-Of-Publication":"year", "Publisher":"publisher", "Image-URL-M":"image"}, inplace=True)

# %%
books.head()
# Out:
#          isbn                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
users = pd.read_csv("BX-Users.csv", sep=";", error_bad_lines=False ,encoding="latin-1")
# Out:
# c:\Users\tanya\anaconda3\envs\books\lib\site-packages\IPython\core\interactiveshell.py:3552: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
users.rename(columns={"User-ID":"user_id", "Location":"location", "Age":"age"}, inplace=True)

# %%
ratings = pd.read_csv("BX-Book-Ratings.csv", sep=";", error_bad_lines=False ,encoding="latin-1")
ratings.head()
# Out:
# c:\Users\tanya\anaconda3\envs\books\lib\site-packages\IPython\core\interactiveshell.py:3552: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
ratings.rename(columns={"User-ID":"user_id", "ISBN":"isbn", "Book-Rating":"rating"}, inplace=True)

# %%
ratings.head()
# Out:
#    user_id        isbn  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
print(books.shape,users.shape, ratings.shape, sep="\n")
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %% [markdown]
# this person who reads multiple books most ratings  --> feature engineering

# %%
d= ratings['user_id'].value_counts()

# %%
d
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: user_id, Length: 105283, dtype: int64

# %%
d.shape
# Out:
# (105283,)

# %% [markdown]
# users who rated more than 200 books

# %%
x = ratings['user_id'].value_counts() > 200

# %%
x
# Out:
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: user_id, Length: 105283, dtype: bool

# %%
x[x].shape
# Out:
# (899,)

# %%
y = x[x].index

# %%
y
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#             260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727,
#             268622, 188951],
#            dtype='int64', length=899)

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#       user_id        isbn  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
# now join rating with books

# %%
rating_with_books = ratings.merge(books, on="isbn")

# %%
rating_with_books.head()
# Out:
#    user_id        isbn  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
number_of_ratings = rating_with_books.groupby('title')['rating'].count().reset_index()

# %%
number_of_ratings
# Out:
#                                                     title  rating
# 0        A Light in the Storm: The Civil War Diary of ...       2
# 1                                   Always Have Popsicles       1
# 2                    Apple Magic (The Collector's series)       1
# 3        Beyond IBM: Leadership Marketing and Finance ...       1
# 4        Clifford Visita El Hospital (Clifford El Gran...       1
# ...                                                   ...     ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...       3
# 160265                                      Ã?Â?lpiraten.       1
# 160266                     Ã?Â?rger mit Produkt X. Roman.       1
# 160267                              Ã?Â?stlich der Berge.       1
# 160268                                  Ã?Â?thique en toc       1
#
# [160269 rows x 2 columns]

# %%
number_of_ratings.head()
# Out:
#                                                title  rating
# 0   A Light in the Storm: The Civil War Diary of ...       2
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Beyond IBM: Leadership Marketing and Finance ...       1
# 4   Clifford Visita El Hospital (Clifford El Gran...       1

# %%
number_of_ratings.rename(columns={"rating":"num_of_ratings"}, inplace=True)

# %%
final_ratings = rating_with_books.merge(number_of_ratings, on="title")

# %%
final_ratings.head()
# Out:
#    user_id        isbn  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
# those books who got atlest 50 ratings
final_ratings = final_ratings[final_ratings['num_of_ratings'] >= 50]
final_ratings
# Out:
#         user_id        isbn  rating  \
# 0        277427  002542730X      10
# 1          3363  002542730X       0
# 2         11676  002542730X       6
# 3         12538  002542730X      10
# 4         13552  002542730X       0
# ...         ...         ...     ...
# 236701   255489  0553579983       7
# 236702   256407  0553579983       0
# 236703   257204  0553579983       0
# 236704   261829  0553579983       0
# 236705   273979  0553579983       0
#
#                                                     title             author  \
# 0       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 1       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 2       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 3       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 4       Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# ...

# %%
final_ratings.head()
# Out:
#    user_id        isbn  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
# lets drop the duplicates
final_ratings.drop_duplicates(['user_id', 'title'], inplace=True)

# %%
final_ratings.isnull().sum()
# Out:
# user_id           0
# isbn              0
# rating            0
# title             0
# author            0
# year              0
# publisher         0
# Image-URL-S       0
# image             0
# Image-URL-L       0
# num_of_ratings    0
# dtype: int64

# %%
#  create a pivot table  --> craeting a pivot table for clustering is so important to show collalborative filteing

book_pivot = final_ratings.pivot_table(index='title', columns='user_id', values='rating')
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (742, 888)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
#  convert pivot table to csr matrix/sparse matrix
#  sparse matrix is a matrix in which most of the elements are zero

#  for the modal nearest neighbour we use the csr metrice

from scipy.sparse import csr_matrix

# %%
books_sparse = csr_matrix(book_pivot)
books_sparse
# Out:
# <742x888 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14942 stored elements in Compressed Sparse Row format>

# %%
type(books_sparse)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
# lets find the nearest neighbour for the first book
#  we will use brute force algorithm to find the nearest neighbour
#  brute force algorithm is a simple algorithm that finds the nearest neighbour by checking all the points in the dataset
#  brute force algorithm is not efficient for large datasets
from sklearn.neighbors import NearestNeighbors  
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(books_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %% [markdown]
# my training is done now we will focus on testing part --> whether it will show or not

# %%
#  if you want to learn about more algorithms you can check the documentation of sklearn
#  https://scikit-learn.org/stable/modules/neighbors.html

# %% [markdown]
# now we will start testing our model

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
book_pivot.iloc[237,:]
# Out:
# user_id
# 254       9.0
# 2276      0.0
# 2766      0.0
# 2977      0.0
# 3363      0.0
#          ...
# 275970    9.0
# 277427    0.0
# 277478    0.0
# 277639    0.0
# 278418    0.0
# Name: Harry Potter and the Chamber of Secrets (Book 2), Length: 888, dtype: float64

# %%
distances, suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1), n_neighbors=6)

# %%
distances
# Out:
# array([[ 0.        , 68.78953409, 69.5413546 , 72.64296249, 76.83098333,
#         77.28518616]])

# %%
suggestion
# Out:
# array([[237, 240, 238, 241, 184, 536]], dtype=int64)

# %%
for i in suggestion[0]:
    print(book_pivot.index[i])
# Out:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Exclusive
# The Cradle Will Fall

# %%
distances, suggestion = model.kneighbors(book_pivot.iloc[200,:].values.reshape(1,-1), n_neighbors=6)

# %%
distances
# Out:
# array([[ 0.        , 22.24859546, 22.60530911, 23.43074903, 23.68543856,
#         24.14539294]])

# %%
suggestion
# Out:
# array([[200, 372, 485, 320, 184, 536]], dtype=int64)

# %%
for i in suggestion[0]:
    print(book_pivot.index[i])
# Out:
# Fatal Cure
# No Safe Place
# Table For Two
# Long After Midnight
# Exclusive
# The Cradle Will Fall

# %%
#  learn how k nearest works
#  we will use similarity score in content based not in collaborative filtering

# %%
#  keeping books name 

book_name = book_pivot.index

# %%
book_name
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='title', length=742)

# %%
book_name[2]
# Out:
# '2nd Chance'

# %%
final_ratings.head()
# Out:
#    user_id        isbn  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
np.where(book_pivot.index == '4 Blondes')[0][0]
# Out:
# 3

# %%
#  final ratings['title'].value_counts()
ids = np.where(final_ratings['title'] == "Harry Potter and the Chamber of Secrets (Book 2)")[0][0]

# %%
final_ratings.iloc[ids]['Image-URL-L']
# Out:
# 'http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg'

# %%
book_name =[]
for book_id in suggestion:
    book_name.append(book_pivot.index[book_id])

# %%
book_name
# Out:
# [Index(['Fatal Cure', 'No Safe Place', 'Table For Two', 'Long After Midnight',
#         'Exclusive', 'The Cradle Will Fall'],
#        dtype='object', name='title')]

# %%
ids_index =[]
for name in book_name[0]:
    id = np.where(final_ratings['title'] == name)[0][0]
    ids_index.append(id)

# %%
ids_index
# Out:
# [16432, 2344, 24285, 7423, 41785, 56125]

# %%
for idx in ids_index:
    url = final_ratings.iloc[idx]['Image-URL-L']
    print(url)
# Out:
# http://images.amazon.com/images/P/0425145638.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0345404777.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0373218400.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0553571818.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0446604232.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0440115450.01.LZZZZZZZ.jpg

# %%
import pickle
pickle.dump(final_ratings, open('artifacts/final_ratings.pkl', 'wb'))
pickle.dump(book_pivot, open('artifacts/book_pivot.pkl', 'wb'))
pickle.dump(model, open('artifacts/model.pkl', 'wb'))
pickle.dump(book_name, open('artifacts/books.pkl', 'wb'))
# pickle.dump(users, open('artifacts/users.pkl', 'wb'))

# %% [markdown]
# testing model

# %%
def recommend_books(book_name):
    ids = np.where(book_pivot.index == book_name)[0][0]
    distances, suggestion = model.kneighbors(book_pivot.iloc[ids,:].values.reshape(1,-1), n_neighbors=6)
    for i in range(len(suggestion)):
        books = book_pivot.index[suggestion[i]]
        for j in books:
            if j == book_name:
                print(f"you searched'{book_name}\n")
                print(f"The suggestion books are:\n")
            else:
                print(f"{j}\n")

# %%
book_name = "2nd Chance"
recommend_books(book_name)
# Out:
# you searched'2nd Chance
#
# The suggestion books are:
#
# The Next Accident
#
# Exclusive
#
# The Ghost
#
# Unspeakable
#
# Last Man Standing
